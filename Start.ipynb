# %% [markdown]
# # Adding a new post

# %%
title = "RISE 5.5.0 is out!"

# %%
tags_list = ['conda', 'Jupyter', 'linux', 'osx', 'pip', 'python', 'reveal', 'RISE', 'slideshow', 'win']

# %%
tags = ', '.join(tags_list)

# !nikola new_post -f ipynb --title="{title}" --tags="{tags}"
# Out:
# [2019-04-27T16:39:22Z] WARNING: Nikola: The RSS_LINKS_APPEND_QUERY option is deprecated, use FEED_LINKS_APPEND_QUERY instead.
# [2019-04-27T16:39:22Z] WARNING: Nikola: The RSS_READ_MORE_LINK option is deprecated, use FEED_READ_MORE_LINK instead.
# [2019-04-27T16:39:22Z] WARNING: Nikola: Could not guess locale for language es, using locale en_US.UTF-8
# [2019-04-27T16:39:22Z] WARNING: Nikola: Please fix your OS locale configuration or use the LOCALES option in conf.py to specify your preferred locale.
# [2019-04-27T16:39:22Z] WARNING: Nikola: Make sure to use an UTF-8 locale to ensure Unicode support.
# Creating New Post
# -----------------
#
# Title: RISE 5.5.0 is out!
# Scanning posts......done!
# [2019-04-27T16:39:26Z] NOTICE: compile_ipynb: No kernel specified, assuming "python3".
# [2019-04-27T16:39:27Z] INFO: new_post: Your post's text is at: posts/rise-550-is-out.ipynb
